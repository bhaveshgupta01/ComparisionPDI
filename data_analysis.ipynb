# %%
import pandas as pd

df = pd.read_csv("dataset/BindingDB/BindingDB_BindingDB_Articles.tsv", sep="\t", low_memory=False)
print(f"Number of rows: {len(df)} ")
# Out:
# Number of rows: 94219

# %%
pd.set_option("display.max_rows", None)
print(df.isna().sum())
# Out:
# BindingDB Reactant_set_id                                                   0
# Ligand SMILES                                                              53
# Ligand InChI                                                             1307
# Ligand InChI Key                                                         1307
# BindingDB MonomerID                                                         0
# BindingDB Ligand Name                                                       0
# Target Name                                                                 0
# Target Source Organism According to Curator or DataSource                  14
# Ki (nM)                                                                 68429
# IC50 (nM)                                                               30585
# Kd (nM)                                                                 91566
# EC50 (nM)                                                               89557
# ...

# %%
import pandas as pd

df = pd.read_csv("dataset/BindingDB/BindingDB_PDSPKi.tsv", sep="\t", low_memory=False)
print(f"Number of rows: {len(df)} ")
# Out:
# Number of rows: 27715

# %%
pd.set_option("display.max_rows", None)
print(df.isna().sum())
# Out:
# BindingDB Reactant_set_id                                                   0
# Ligand SMILES                                                               0
# Ligand InChI                                                              933
# Ligand InChI Key                                                          933
# BindingDB MonomerID                                                         0
# BindingDB Ligand Name                                                       0
# Target Name                                                                 0
# Target Source Organism According to Curator or DataSource                   0
# Ki (nM)                                                                     0
# IC50 (nM)                                                               27715
# Kd (nM)                                                                 27715
# EC50 (nM)                                                               27715
# ...
